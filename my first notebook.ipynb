# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
# Hardware is Physical parts of a computer that you can touch and see.
# Examples: CPU, keyboard, monitor, hard drive.
# Software is programs or instructions that tells the computer what to do.
# Example: Microsoft word, operating system.
